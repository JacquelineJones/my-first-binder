# %%
## Question 1
#### In the table below, fill in the definition column with a short (no more than two sentence) definition for each vocab word. If it can be summarized by a formula, give the formula. 

| Vocab Word | Definition |
|:--------|:--------|
| **One-hot coding** | Assign numerical values to categorical variables |
| **Feature selection*** | When building a model, choose the most relevent variables to improve performance |
| **Classifier** |An algorithm that aligns input data to predefined classes   |
| **Precision** |Proportion of correctly predicted positive cases out all predicted positive cases  |
| **Recall** | Proportion of correctly predicted positive cases out all actual positive cases |
| **F1 Score** | The mean of precisiion and recall |
| **Parsimonious model** | A simple model that explains the data with as few parameters as possible  |
| **Ridge regression** | A linear regression technique that penalizes large coefficients |
| **LASSO regression** | Linear regression technique that has the ability to shink coeffcients to zero  |
| **Cross validation** | Splitting the data for training and performance generalization |
| **Tree based methods** | Methods that include decision trees |

*Just give the general idea.

# %%
Question 2

a) What shape does a perfect classifier look like on an ROC curve? What about a bad classifier?
A perfect classifier will go straight up to the left side and then across the top. The AUC will be 1 whereas a bad
classifier will have a diagonal line from (0,0) to (1,1).

b) Think about the formula for an F1 score. What does it mean when the F1 score is close to 1? Close to 0?
When the F1 score is close to one both the precision and recall are high, signalling it is a strong and balanced model. 
When it is close to 0, precision and/or recall are very low and the model is performing poorly.

# %%
## Question 3
#### Compare the following aspects of linear vs. logistic regression.
|  | Linear | Logistic |
|:--------|:--------|:--------|
| **Chart Shape** | Straight  | S-shaped  |
| **Dependent Variable Type** | Continuous | Binary |
| **Purpose** (regression or classification) | Regression | Classification |
| **Range of output variable** ($y_i$ or $p_i$) | Infinite  | 0 1 |
| **Method*** | Ordinary least squares  | Maximum likelihood estimation |
| **Example of use** | Prediction if a behavior is associated with response level  | Prediction of if a behavior is associated with a diagnosis |  
  
*Meaning ordinary least squares or maximum likelihood estimation

# %%
## Question 4
#### Why is it important to train then test our model? How do we do that? (2-3 sentences. Not looking for code, just general explanation)
#Its important to train and then test the model because it signals that it can be generalized to additional data. This avoids overfitting and creates a more usable model in a variety of contexts. #Its important to train and then test the model because it signals that it can be generalized to additional data. This avoids overfitting and creates a more usable model in a variety of contexts. .

# %%
#Question 5
#a load data
install.packages("dplyr")
install.packages("tidyverse")
install.packages("stringr")
library(dplyr)
library(tidyverse)
library(stringr)
# Out:
# The downloaded binary packages are in
# 	/var/folders/c1/3jgbfbvj7dv1_6065q6b0_300000gn/T//Rtmpr2VTlX/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/c1/3jgbfbvj7dv1_6065q6b0_300000gn/T//Rtmpr2VTlX/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/c1/3jgbfbvj7dv1_6065q6b0_300000gn/T//Rtmpr2VTlX/downloaded_packages

# %%
housing <- read.csv("housing.csv")
head(housing)

names(housing) <- names(housing) %>%
  str_replace_all("-","_") %>%
  str_replace_all("[^_A-Za-z0-9]*","") %>%
  str_to_lower()

#b scale and split data
scaled <- scale(housing)

housing_num <- housing %>% select(where(is.numeric)) %>%
  mutate(across(where(is.numeric), scale))

#split 75% training
set.seed(123)
train <- runif(nrow(housing_num)) < 0.75
test <- !train

#c fit model
f <- median_house_value ~ housing_median_age + total_rooms + population + households+ median_income
m <- lm(f, data=housing_num %>% filter(train))
summary(m)

# 6. Prediction on test data.
dx <- housing_num %>% filter(test)

dx <- dx %>% 
  mutate(median_house_pred = predict(m, newdata = as.data.frame(dx)))

# 7. Predicted vs actual plot.
ggplot(dx, aes(median_house_value, median_house_pred)) + geom_point() + geom_segment(aes(x=0,y=0,xend=1,yend=1))

# 8. Residual density plot.
ggplot(dx, aes(median_house_value-median_house_pred)) + geom_density()
# Out:
#   longitude latitude housing_median_age total_rooms population households
# 1 -122.23   37.88    41                  880         322        126
# 2 -122.22   37.86    21                 7099        2401       1138
# 3 -122.24   37.85    52                 1467         496        177
# 4 -122.25   37.85    52                 1274         558        219
# 5 -122.25   37.85    52                 1627         565        259
# 6 -122.25   37.85    52                  919         413        193
#   median_income median_house_value
# 1 8.3252        452600
# 2 8.3014        358500
# 3 7.2574        352100
# 4 5.6431        341300
# 5 3.8462        342200
# 6 4.0368        269700
# Call:
# lm(formula = f, data = housing_num %>% filter(train))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.3465 -0.4203 -0.0982  0.3049  4.0320
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -0.000993   0.005239   -0.19     0.85
# housing_median_age  0.204298   0.005647   36.18   <2e-16 ***
# total_rooms        -0.251487   0.015843  -15.87   <2e-16 ***
# population         -0.428133   0.013326  -32.13   <2e-16 ***
# households          0.735140   0.017622   41.72   <2e-16 ***
# median_income       0.755787   0.006002  125.92   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6536 on 15558 degrees of freedom
# Multiple R-squared:  0.5711,	Adjusted R-squared:  0.571
# F-statistic:  4144 on 5 and 15558 DF,  p-value: < 2.2e-16
# Warning message in geom_segment(aes(x = 0, y = 0, xend = 1, yend = 1)):
# “All aesthetics have length 1, but the data has 5076 rows.
# ℹ Please consider using `annotate()` or provide this layer with data containing
#   a single row.”
# plot without title
# plot without title

# %%
#a) First, load the diabetes.csv data set. 
#Look at the data in some useful way. Why is logistic regression appropriate here?
diabetes <- read.csv("diabetes.csv")
head(diabetes)

#b) Scale data and split it 75/25 training/testing. Set seed = 123.
scaled <- scale(diabetes)

diabetes_num <- diabetes %>% select(where(is.numeric)) %>%
  mutate(across(where(is.numeric), scale))

#split 75% training
set.seed(123)
train <- runif(nrow(diabetes_num)) < 0.75
test <- !train

#c) Fit the model.
f <- Outcome ~ Pregnancies + Glucose + BloodPressure + SkinThickness + Insulin + BMI + DiabetesPedigreeFunction + Age
m <- glm(f, data=housing_num %>% filter(train))
summary(m)

#d) Make predictions on test data. Print a table with the number of true positives, false positives, true negatives, false negatives, and accuracy.
#e) Fit a LASSO-regularized logistic regression model. Again, set seed = 123. Which variables are the most important (which ones don't go to zero)? How does the LASSO model affect the accuracy?
#f) Make a plot of actual vs. predicted values for the LASSO model.
# Out:
#   Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# 1 6           148     72            35              0     33.6
# 2 1            85     66            29              0     26.6
# 3 8           183     64             0              0     23.3
# 4 1            89     66            23             94     28.1
# 5 0           137     40            35            168     43.1
# 6 5           116     74             0              0     25.6
#   DiabetesPedigreeFunction Age Outcome
# 1 0.627                    50  1
# 2 0.351                    31  0
# 3 0.672                    32  1
# 4 0.167                    21  0
# 5 2.288                    33  1
# 6 0.201                    30  0
# Error in `filter()`:
# ℹ In argument: `train`.
# Caused by error:
# ! `..1` must be of size 20640 or 1, not size 768.
# Traceback:
#
# 1. eval(mf, parent.frame())
# 2. eval(mf, parent.frame())
# 3. stats::model.frame(formula = f, data = housing_num %>% filter(train),
#  .     drop.unused.levels = TRUE)
# 4. model.frame.default(formula = f, data = housing_num %>% filter(train),
#  .     drop.unused.levels = TRUE)
# 5. is.data.frame(data)
# 6. housing_num %>% filter(train)
# 7. filter(., train)
# 8. filter.data.frame(., train)
# 9. filter_rows(.data, dots, by)
# 10. filter_eval(dots, mask = mask, error_call = error_call, user_env = user_env)
# 11. withCallingHandlers(mask$eval_all_filter(dots, env_filter), error = dplyr_error_handler(dots = dots,
#   .     mask = mask, bullets = filter_bullets, error_call = error_call),
#   .     warning = function(cnd) {
#   .         local_error_context(dots, i, mask)
#   .         warning_handler(cnd)
#   .     }, `dplyr:::signal_filter_one_column_matrix` = function(e) {
#   .         warn_filter_one_column_matrix(env = error_call, user_env = user_env)
#   .     }, `dplyr:::signal_filter_across` = function(e) {
#   .         warn_filter_across(env = error_call, user_env = user_env)
#   .     }, `dplyr:::signal_filter_data_frame` = function(e) {
#   .         warn_filter_data_frame(env = error_call, user_env = user_env)
#   .     })
# 12. mask$eval_all_filter(dots, env_filter)
# 13. eval()
# 14. dplyr_internal_error("dplyr:::filter_incompatible_size", list(
#   .     index = 1L, size = 768L, expected_size = 20640L))
# 15. abort(class = c(class, "dplyr:::internal_error"), dplyr_error_data = data)
# 16. signal_abort(cnd, .file)
# 17. signalCondition(cnd)
# 18. (function (cnd)
#   . {
#   .     local_error_context(dots, i = frame[[i_sym]], mask = mask)
#   .     if (inherits(cnd, "dplyr:::internal_error")) {
#   .         parent <- error_cnd(message = bullets(cnd))
#   .     }
#   .     else {
#   .         parent <- cnd
#   .     }
#   .     message <- c(cnd_bullet_header(action), i = if (has_active_group_context(mask)) cnd_bullet_cur_group_label())
#   .     abort(message, class = error_class, parent = parent, call = error_call)
#   . })(structure(list(message = "", trace = structure(list(call = list(
#   .     IRkernel::main(), kernel$run(), handle_shell(), executor$execute(msg),
#   .     tryCatch(evaluate(request$content$code, envir = .GlobalEnv,
#   .         output_handler = oh, stop_on_error = 1L), interrupt = function(cond) {
#   .         log_debug("Interrupt during execution")
#   .         interrupted <<- TRUE
#   .     }, error = .self$handle_error), tryCatchList(expr, classes,
#   .         parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), doTryCatch(return(expr), name, parentenv,
#   .         handler), tryCatchList(expr, names[-nh], parentenv, handlers[-nh]),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     withRestarts(with_handlers({
#   .         for (expr in tle$exprs) {
#   .             ev <- withVisible(eval(expr, envir))
#   .             watcher$capture_plot_and_output()
#   .             watcher$print_value(ev$value, ev$visible, envir)
#   .         }
#   .         TRUE
#   .     }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE),
#   .     withRestartList(expr, restarts), withOneRestart(withRestartList(expr,
#   .         restarts[-nr]), restarts[[nr]]), doWithOneRestart(return(expr),
#   .         restart), withRestartList(expr, restarts[-nr]), withOneRestart(expr,
#   .         restarts[[1L]]), doWithOneRestart(return(expr), restart),
#   .     with_handlers({
#   .         for (expr in tle$exprs) {
#   .             ev <- withVisible(eval(expr, envir))
#   .             watcher$capture_plot_and_output()
#   .             watcher$print_value(ev$value, ev$visible, envir)
#   .         }
#   .         TRUE
#   .     }, handlers), eval(call), eval(call), withCallingHandlers(code,
#   .         message = `<fn>`, warning = `<fn>`, error = `<fn>`),
#   .     withVisible(eval(expr, envir)), eval(expr, envir), eval(expr,
#   .         envir), glm(f, data = housing_num %>% filter(train)),
#   .     eval(mf, parent.frame()), eval(mf, parent.frame()), stats::model.frame(formula = f,
#   .         data = housing_num %>% filter(train), drop.unused.levels = TRUE),
#   .     model.frame.default(formula = f, data = housing_num %>% filter(train),
#   .         drop.unused.levels = TRUE), is.data.frame(data), housing_num %>%
#   .         filter(train), filter(., train), filter.data.frame(.,
#   .         train), filter_rows(.data, dots, by), filter_eval(dots,
#   .         mask = mask, error_call = error_call, user_env = user_env),
#   .     withCallingHandlers(mask$eval_all_filter(dots, env_filter),
#   .         error = dplyr_error_handler(dots = dots, mask = mask,
#   .             bullets = filter_bullets, error_call = error_call),
#   .         warning = function(cnd) {
#   .             local_error_context(dots, i, mask)
#   .             warning_handler(cnd)
#   .         }, `dplyr:::signal_filter_one_column_matrix` = function(e) {
#   .             warn_filter_one_column_matrix(env = error_call, user_env = user_env)
#   .         }, `dplyr:::signal_filter_across` = function(e) {
#   .             warn_filter_across(env = error_call, user_env = user_env)
#   .         }, `dplyr:::signal_filter_data_frame` = function(e) {
#   .             warn_filter_data_frame(env = error_call, user_env = user_env)
#   .         }), mask$eval_all_filter(dots, env_filter), eval(), dplyr_internal_error("dplyr:::filter_incompatible_size",
#   .         `<named list>`), abort(class = c(class, "dplyr:::internal_error"),
#   .         dplyr_error_data = data)), parent = c(0L, 1L, 2L, 3L,
#   . 4L, 5L, 6L, 7L, 6L, 9L, 10L, 4L, 12L, 13L, 14L, 15L, 14L, 17L,
#   . 18L, 12L, 20L, 21L, 20L, 12L, 12L, 25L, 0L, 27L, 28L, 0L, 0L,
#   . 31L, 0L, 0L, 0L, 35L, 36L, 37L, 37L, 39L, 0L, 41L), visible = c(TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, FALSE), namespace = c("IRkernel",
#   . NA, "IRkernel", NA, "base", "base", "base", "base", "base", "base",
#   . "base", "evaluate", "base", "base", "base", "base", "base", "base",
#   . "base", "evaluate", "base", "base", "base", "base", "base", "base",
#   . "stats", "base", "base", "stats", "stats", "base", NA, "dplyr",
#   . "dplyr", "dplyr", "dplyr", "base", NA, "dplyr", "dplyr", "rlang"
#   . ), scope = c("::", NA, "local", NA, "::", "local", "local", "local",
#   . "local", "local", "local", "::", "::", "local", "local", "local",
#   . "local", "local", "local", ":::", "::", "::", "::", "::", "::",
#   . "::", "::", "::", "::", "::", "::", "::", NA, "::", ":::", ":::",
#   . ":::", "::", NA, "local", ":::", "::"), error_frame = c(FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   . FALSE, FALSE, FALSE, TRUE, FALSE)), row.names = c(NA, -42L), version = 2L, class = c("rlang_trace",
#   . "rlib_trace", "tbl", "data.frame")), parent = NULL, dplyr_error_data = list(
#   .     index = 1L, size = 768L, expected_size = 20640L), rlang = list(
#   .     inherit = TRUE), call = dplyr_internal_error("dplyr:::filter_incompatible_size",
#   .     list(index = 1L, size = 768L, expected_size = 20640L)), use_cli_format = TRUE), class = c("dplyr:::filter_incompatible_size",
#   . "dplyr:::internal_error", "rlang_error", "error", "condition"
#   . )))
# 19. abort(message, class = error_class, parent = parent, call = error_call)
# 20. signal_abort(cnd, .file)
# 21. signalCondition(cnd)

# %%
#Question 6
#a) First, load the diabetes.csv data set. Look at the data in some useful way. Why is logistic regression appropriate here?¶


diabetes<- read_csv("diabetes.csv")
#### b) Scale data and split it 75/25 training/testing. Set seed = 123.


set.seed(123)

diabetes_num <- diabetes %>%
  select(where(is.numeric)) %>%
  mutate(across(where(is.numeric), scale))

train_index <- runif(nrow(diabetes_num)) < 0.75

train <- diabetes_num[train_index, ]
test <- diabetes_num[!train_index, ]

#C. Fit model
	

model_log <- glm(Outcome ~ ., data = train, family = "binomial")
summary(model_log)

# %%
#d
# d) Predictions and performance metrics
pred_probs <- predict(model_log, newdata = test, type = "response")
pred_class <- ifelse(pred_probs > 0.5, 1, 0)

# Confusion matrix
conf_matrix <- table(Predicted = pred_class, Actual = test$Outcome)
conf_matrix

# Extract performance metrics
TP <- conf_matrix[2, 2]
TN <- conf_matrix[1, 1]
FP <- conf_matrix[2, 1]
FN <- conf_matrix[1, 2]

accuracy <- (TP + TN) / sum(conf_matrix)

cat("True Positives:", TP, "\n")
cat("False Positives:", FP, "\n")
cat("True Negatives:", TN, "\n")
cat("False Negatives:", FN, "\n")
cat("Accuracy:", round(accuracy, 4), "\n")

#e
install.packages("glmnet")
library(glmnet)

set.seed(123)

# Prepare matrices for glmnet
x_train <- as.matrix(train %>% select(-Outcome))
y_train <- train$Outcome

# Fit LASSO (alpha = 1 means pure LASSO)
lasso_model <- cv.glmnet(x_train, y_train, alpha = 1, family = "binomial")

# Plot cross-validation curve
plot(lasso_model)

# Find coefficients at best lambda
coef_lasso <- coef(lasso_model, s = "lambda.min")
coef_lasso

# Predict on test data
x_test <- as.matrix(test %>% select(-Outcome))
pred_probs_lasso <- predict(lasso_model, newx = x_test, s = "lambda.min", type = "response")
pred_class_lasso <- ifelse(pred_probs_lasso > 0.5, 1, 0)

# Confusion matrix
conf_matrix_lasso <- table(Predicted = pred_class_lasso, Actual = test$Outcome)
conf_matrix_lasso

# Accuracy
accuracy_lasso <- sum(diag(conf_matrix_lasso)) / sum(conf_matrix_lasso)
cat("LASSO Model Accuracy:", round(accuracy_lasso, 4), "\n")

# %%
#f

library(ggplot2)

lasso_plot_data <- data.frame(
  Actual = test$Outcome,
  Predicted_Prob = as.numeric(pred_probs_lasso)
)

ggplot(lasso_plot_data, aes(x = Actual, y = Predicted_Prob)) +
  geom_jitter(width = 0.1, height = 0, alpha = 0.6, color = "blue") +
  geom_smooth(method = "loess", color = "red", se = FALSE) +
  labs(
    title = "Actual vs Predicted Probabilities (LASSO Logistic Regression)",
    x = "Actual Outcome",
    y = "Predicted Probability of Diabetes"
  ) +
  theme_minimal()
